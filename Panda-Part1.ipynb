# %% [markdown]
# # Pandas-Part1

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd #pd is an alias

# %%
# contrl-V for pasting the path!

df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/6110/GitHub/6110-Fall-2025/Data/dataset2.xlsx", sheet_name = "Admission")
df  #df is an ref variable pointing to an object of type DataFrame
# DataFrame is a type --> rows x columns
# Out:
#       Student Decision   SAT Female  HSGPA
# 0           1     Deny   873     No   2.57
# 1           2     Deny   861    Yes   2.65
# 2           3    Admit  1416     No   4.02
# 3           4     Deny  1135     No   2.63
# 4           5    Admit  1381     No   4.20
# ...       ...      ...   ...    ...    ...
# 1225     1226     Deny   990     No   3.83
# 1226     1227    Admit  1439     No   2.61
# 1227     1228     Deny   873    Yes   3.96
# 1228     1229     Deny  1236     No   2.51
# 1229     1230    Admit  1410     No   4.28
#
# [1230 rows x 5 columns]

# %%
df.head()
# Out:
#    Student Decision   SAT Female  HSGPA
# 0        1     Deny   873     No   2.57
# 1        2     Deny   861    Yes   2.65
# 2        3    Admit  1416     No   4.02
# 3        4     Deny  1135     No   2.63
# 4        5    Admit  1381     No   4.20

# %%
df.shape # shape is a very useful attribute available in Pandas package!
#rows x columns
# Out:
# (1230, 5)

# %%
df.describe() #describe () is a method avaialble in Pandas package
# Out:
#            Student          SAT        HSGPA
# count  1230.000000  1230.000000  1230.000000
# mean    615.500000  1197.343902     3.362756
# std     355.214724   232.526456     0.652488
# min       1.000000   800.000000     2.210000
# 25%     308.250000   996.000000     2.790000
# 50%     615.500000  1197.000000     3.360000
# 75%     922.750000  1397.750000     3.925000
# max    1230.000000  1600.000000     4.510000

# %%
df[["SAT"]] #col subsetting, col slicing
# Out:
#        SAT
# 0      873
# 1      861
# 2     1416
# 3     1135
# 4     1381
# ...    ...
# 1225   990
# 1226  1439
# 1227   873
# 1228  1236
# 1229  1410
#
# [1230 rows x 1 columns]

# %%
mean_SAT = df[["SAT"]].mean()
mode_SAT = df[["SAT"]].mode()
median_SAT = df[["SAT"]].median()

print("Mean SAT", mean_SAT)
print("mode SAT", mode_SAT)
print("Median SAT", median_SAT)
# Out:
# Mean SAT SAT    1197.343902
# dtype: float64
# mode SAT     SAT
# 0  1587
# Median SAT SAT    1197.0
# dtype: float64

# %%
#Multiple column subsetting
df[["SAT", "HSGPA"]]
# Out:
#        SAT  HSGPA
# 0      873   2.57
# 1      861   2.65
# 2     1416   4.02
# 3     1135   2.63
# 4     1381   4.20
# ...    ...    ...
# 1225   990   3.83
# 1226  1439   2.61
# 1227   873   3.96
# 1228  1236   2.51
# 1229  1410   4.28
#
# [1230 rows x 2 columns]

# %%
# Row subsetting!
# DataFrame --> index starts at 0, index is a label (not a numerical value)

#iloc vs loc for row subsetting

#iloc; i indciates it is an interger based;
df.iloc[0:4]
#0:4 --> start at first row  --> end at the forth row (ends at n-1 (4-1 =3))
# Out:
#    Student Decision   SAT Female  HSGPA
# 0        1     Deny   873     No   2.57
# 1        2     Deny   861    Yes   2.65
# 2        3    Admit  1416     No   4.02
# 3        4     Deny  1135     No   2.63

# %%
df.iloc[5:15] #start at index 5, ends at 15-1 = 14
# Out:
#     Student Decision   SAT Female  HSGPA
# 5         6     Deny  1114    Yes   2.43
# 6         7    Admit  1544     No   3.20
# 7         8    Admit  1356     No   4.29
# 8         9    Admit  1134     No   4.32
# 9        10     Deny  1061    Yes   3.32
# 10       11     Deny  1074     No   3.35
# 11       12    Admit  1520     No   4.04
# 12       13     Deny  1190    Yes   2.97
# 13       14     Deny   979    Yes   2.96
# 14       15     Deny   816     No   3.83

# %%
df.iloc[1200:]

# %%
# loc --> label based
df.loc[0:4]  # start at lable 0 , ends at label 4
# Out:
#    Student Decision   SAT Female  HSGPA
# 0        1     Deny   873     No   2.57
# 1        2     Deny   861    Yes   2.65
# 2        3    Admit  1416     No   4.02
# 3        4     Deny  1135     No   2.63
# 4        5    Admit  1381     No   4.20

# %%
print(df.iloc[0:4])
print(df.loc[0:4])
# Out:
#    Student Decision   SAT Female  HSGPA
# 0        1     Deny   873     No   2.57
# 1        2     Deny   861    Yes   2.65
# 2        3    Admit  1416     No   4.02
# 3        4     Deny  1135     No   2.63
#    Student Decision   SAT Female  HSGPA
# 0        1     Deny   873     No   2.57
# 1        2     Deny   861    Yes   2.65
# 2        3    Admit  1416     No   4.02
# 3        4     Deny  1135     No   2.63
# 4        5    Admit  1381     No   4.20

# %%
#Show the first 10 studdents
df.iloc[0:10]
# Out:
#    Student Decision   SAT Female  HSGPA
# 0        1     Deny   873     No   2.57
# 1        2     Deny   861    Yes   2.65
# 2        3    Admit  1416     No   4.02
# 3        4     Deny  1135     No   2.63
# 4        5    Admit  1381     No   4.20
# 5        6     Deny  1114    Yes   2.43
# 6        7    Admit  1544     No   3.20
# 7        8    Admit  1356     No   4.29
# 8        9    Admit  1134     No   4.32
# 9       10     Deny  1061    Yes   3.32

# %%
#Show the first 10
df.loc[0:9]
# Out:
#    Student Decision   SAT Female  HSGPA
# 0        1     Deny   873     No   2.57
# 1        2     Deny   861    Yes   2.65
# 2        3    Admit  1416     No   4.02
# 3        4     Deny  1135     No   2.63
# 4        5    Admit  1381     No   4.20
# 5        6     Deny  1114    Yes   2.43
# 6        7    Admit  1544     No   3.20
# 7        8    Admit  1356     No   4.29
# 8        9    Admit  1134     No   4.32
# 9       10     Deny  1061    Yes   3.32

# %%
#What is the average score of SAT of the fisst 20 stduents?

df2 = df.iloc[0:20]
df2[['SAT']]
df2[['SAT']].mean()
# Out:
# SAT    1181.0
# dtype: float64

# %%
#What is the mean score of SAT of the first 20 students?
df.iloc[0:20][['SAT']].mean()
# Out:
# SAT    1181.0
# dtype: float64

# %%
#show me the median score of students from 4th row --> 7th row (inclusive)
df3 = df.iloc[3:7]
df3[['SAT']]
df3[['SAT']].median()
# Out:
# SAT    1258.0
# dtype: float64

# %%
#show me the median score of students from 4th row --> 7th row (inclusive)
df4 = df.loc[3:6]
df4[['SAT']].median()
# Out:
# SAT    1258.0
# dtype: float64

# %%
df.iloc[0:20][['HSGPA']].mean()
# Out:
# HSGPA    3.321429
# dtype: float64
